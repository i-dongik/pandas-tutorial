# %%
import numpy as np

# %% [markdown]
# # 신경망
# * 퍼셉트론 알고리즘을 사용하면 복잡한 함수도 표현할 수 있지만, 가중치를 설정하는 작업은 수동으로 해야한다는 점이 있습니다.
# * 신경망을 사용하면 가중치의 값을 데이터로부터 자동으로 학습하는 능력이 신경망의 중요한 성질입니다.

# %% [markdown]
# # 활성화 함수의 종류

# %% [markdown]
# ## 시그모이드 함수
# * 시그모이드 함수(sigmoid function)
#
# ![image.png](attachment:43bebbb8-0f81-4af4-b70e-dc2afa7d47bd.png)

# %% [markdown]
# ### 자연상수의 의미
# * 자연 상수 e는 어떤 대상이 얼마만큼 성장했는지를 알려주는 수

# %% [markdown]
# ![image.png](attachment:894a0d2c-bce3-42a8-864e-73f4cfd4e4c9.png)

# %% [markdown]
# * 은행의 1년 만기 복리 금리가 연 100% 상품

# %%
(1 + 1/1) ** 1
# Out:
# 2.0

# %% [markdown]
# * 6개월로 줄여서 계산하면..

# %%
(1 + 1/2) ** 2
# Out:
# 2.25

# %%
(1 + 1/3) ** 3
# Out:
# 2.37037037037037

# %%
(1 + 1/100) ** 100
# Out:
# 2.7048138294215285

# %%
for x in range(1,100000, 10000):
    print ( (1 + 1 / x) ** x)
# Out:
# 2.0
# 2.7181459404132355
# 2.718213877920689
# 2.7182365266521105
# 2.718247851567573
# 2.7182546466951907
# 2.718259176817358
# 2.7182624126906547
# 2.7182648395812037
# 2.7182667272205876

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %% [markdown]
# ## 다차원 배열

# %%
import numpy as np

# %%
A = np.array([[1,2,3,4]])

# %%
B = np.array([1,2,3,4])

# %% [markdown]
# * 넘파이 배열의 구조를 확인

# %%
A.shape
# Out:
# (1, 4)

# %% [markdown]
# * 차원을 확인

# %%
A.ndim
# Out:
# 2

# %%
B.shape
# Out:
# (4,)

# %%
B.ndim
# Out:
# 1

# %%
C = np.array([[1,2], [3,4], [5,6]])

# %%
C.shape
# Out:
# (3, 2)

# %%
C
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
C1 = np.arange(1,7)

# %%
C1.reshape(3,2)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# * 넘파이의 2차원 배열을 행렬이라고 했을 때 행과 열은 아래와 같이 정의된다.

# %% [markdown]
# ![image.png](attachment:c5e827e2-76de-4086-96c0-58c6858b2e94.png)

# %% [markdown]
# ## 행렬의 내적(행렬 곱)

# %% [markdown]
# * 넘파이 및 앞으로 하게 될 딥러닝 패키지는 수학을 기반으로 하기 때문에 수학적으로 오류가 있으면 코드에서 오류가 발생합니다.
# * 그렇기 때문에 행렬의 내적의 규칙을 잘 지켜야합니다.

# %% [markdown]
# ![image.png](attachment:3c9b4518-9264-4d43-86a7-432c23be1e58.png)

# %%
A = np.arange(1,5).reshape(2,2)

# %%
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
B = np.arange(5,9).reshape(2,2)

# %%
B
# Out:
# array([[5, 6],
#        [7, 8]])

# %%
np.dot(A,B)
# Out:
# array([[19, 22],
#        [43, 50]])

# %%
A1 = np.arange(1,101).reshape(-1, 5)

# %%
A1.shape
# Out:
# (20, 5)

# %%
B1 = np.arange(201, 251).reshape(5, -1)

# %%
B1.shape
# Out:
# (5, 10)

# %%
np.dot( A1, B1).shape
# Out:
# (20, 10)

# %%
D = np.array([[[[3],[4]]]])

# %%
D.shape
# Out:
# (1, 1, 2, 1)

# %%
D.ndim
# Out:
# 3

# %% [markdown]
# * 아래 그림은 행렬의 내적의 규칙을 나타냅니다.

# %% [markdown]
# ![image.png](attachment:e6ebbc15-ac73-4c91-8f00-fe962e5749a0.png)

# %% [markdown]
# ![image.png](attachment:50a4ba23-2cfc-4a39-92fa-8f53d78311de.png)

# %%
A = np.arange(1,7).reshape(3,2)

# %%
np.dot(A, np.array([3,2]))
# Out:
# array([ 7, 17, 27])

# %%
np.array([3,2]).shape
# Out:
# (2,)

# %% [markdown]
# * 간단한 신경망의 구조를 행렬로 표현하겠습니다.

# %% [markdown]
# ![image.png](attachment:9a2ca6b5-3776-44e8-bda4-479a8b66ee4e.png)

# %% [markdown]
# ## 3층 신경망 구현하기

# %% [markdown]
# ![image.png](attachment:a8c58234-0979-4ffb-97d4-edfe974d9e3d.png)

# %% [markdown]
# ![image.png](attachment:31119fed-cc4d-48a2-854d-181f2b2a3bab.png)

# %% [markdown]
# ![image.png](attachment:b6d1c93f-6ab8-451a-a78d-c2f34b850827.png)

# %% [markdown]
# ![image.png](attachment:a1599405-ffc0-4226-b49c-7d9568186d82.png)

# %% [markdown]
# ![image.png](attachment:8aa6c3d5-9d16-432b-b8b2-1638a18a421e.png)

# %%
X = np.array([1., 0.5])
W1 = np.array([[0.1, 0.3, 0.5], [0.2, 0.4, 0.6]])
B1 = np.array([0.1, 0.2, 0.3])

# %%
X.shape
# Out:
# (2,)

# %%
W1.shape
# Out:
# (2, 3)

# %%
A1 = np.dot(X, W1) + B1

# %%
Z1 = sigmoid(A1)

# %%
W2 = np.array([[0.1, 0.4], [0.2, 0.5], [0.3, 0.6]])
B2 = np.array([0.1, 0.2])

# %%
Z2 = sigmoid(np.dot(Z1, W2) + B2)

# %%
Z2
# Out:
# array([0.62624937, 0.7710107 ])

# %%
W3 = np.array([[0.1,0.3], [0.2, 0.4]])
B3 = np.array([0.1, 0.2])

# %%
Y = identity_function(np.dot(Z2, W3) + B3)

# %%
Y
# Out:
# array([0.31682708, 0.69627909])

# %% [markdown]
# ## 출력층 설계

# %% [markdown]
# ### softmax function

# %% [markdown]
# ![image.png](attachment:1056f0c3-d317-46ea-9e2c-69a7cb51f565.png)

# %% [markdown]
# * 컴퓨터는 수를 4byte나 8byte와 같이 크기가 유한한 데이터로 다룹니다. 다시 이야기하면 숫자의 표현 범위가 한정되어 있는데 그 값을 넘어버리면 값을 제대로 표현할수 없는데 이를 오버플로워라합니다.

# %%
a = np.array([0.3, 2.9, 4.0])
exp_a = np.exp(a)

# %%
exp_a
# Out:
# array([ 1.34985881, 18.17414537, 54.59815003])

# %%
sum_exp_a = np.sum(exp_a)

# %%
np.sum(exp_a / sum_exp_a)
# Out:
# 1.0

# %%
exp_a / sum_exp_a
# Out:
# array([0.01821127, 0.24519181, 0.73659691])

# %% [markdown]
# ## mnist

# %%
import numpy as np
import sys
import os
sys.path.append(os.pardir)
from dataset.mnist import load_mnist

# %%
(x_train, t_train), (x_test, t_test) = \
    load_mnist(normalize=True, one_hot_label=False)

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
x_test.shape
# Out:
# (10000, 784)

# %%
from PIL import Image

# %%
img_x = x_train[10].reshape(28, 28)

# %%
t_train[10]
# Out:
# 3

# %%
from matplotlib.pyplot import imshow

# %%
imshow(img_x)

# %% [markdown]
# ### 미니배치

# %% [markdown]
# ![image.png](attachment:2d4f2e8e-9bcd-4414-9c77-c913451b8626.png)

# %% [markdown]
# ![image.png](attachment:ac09be2d-a9c3-4adc-b2cc-bfbf8b3539b1.png)

# %% [markdown]
# ### 예제
# * 아래 예제에서는 학습이 완료된 파일을 제공합니다.
#     * 학습이란 최적의 weight값을 찾아가는 과정인데 아래 예제에선 weight 값을 제공합니다. 곧 학습된 모델을 제공합니다.

# %%
import pickle

# %%
def get_data():
    (x_train, t_train), (x_test, t_test) = \
        load_mnist(flatten=True, normalize=True, one_hot_label=False)
    return x_test, t_test


def init_network():
    with open("sample_weight.pkl", 'rb') as f:
        # 학습된 가중치 매개변수가 담긴 파일
        # 학습 없이 바로 추론을 수행
        network = pickle.load(f)

    return network


def predict(network, x):
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1, W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2, W3) + b3
    y = softmax(a3)

    return y


x, t = get_data()
network = init_network()
accuracy_cnt = 0

# %%
network['W3'].shape
# Out:
# (100, 10)

# %% [markdown]
# * 모델에 값을 전달해서 출력화는 과정을 추론이라고 하는데 아래는 사진을 한장씩 추론합니다.

# %%
# %%time
for i in range(len(x)):
    y = predict(network, x[i])
    p = np.argmax(y)  # 확률이 가장 높은 원소의 인덱스를 얻는다.
    if p == t[i]:
        accuracy_cnt += 1

print("Accuracy:" + str(float(accuracy_cnt) / len(x)))  # Accuracy:0.9352
# Out:
# Accuracy:2.8058
# Wall time: 364 ms

# %%
np.argmax(y)
# Out:
# 7

# %%
t[i]
# Out:
# 7

# %%
# %%time


# 3.6.3 배치 처리
batch_size = 1000

for i in range(0, len(x), batch_size):
    x_batch = x[i:i+batch_size]
    y_batch = predict(network, x_batch)
    p = np.argmax(y_batch, axis=1)
    accuracy_cnt += np.sum(p == t[i:i+batch_size])

print("Accuracy:" + str(float(accuracy_cnt) / len(x)))  # Accuracy:0.9352
# Out:
# Accuracy:4.6762
# Wall time: 20.6 ms
